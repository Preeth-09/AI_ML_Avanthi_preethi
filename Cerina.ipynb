# %% [markdown]
# <a href="https://colab.research.google.com/github/Preeth-09/AI_ML_Avanthi_preethi/blob/main/Cerina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('/content/Homestays_Data(in).csv')
df
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
df["host_since"].isnull().sum()
# Out:
# 188

# %%
non_date_values = df["host_since"][~df["host_since"].astype(str).str.isdigit()]

# %%
def calculate_host_tenure(df):
  """
  Calculates the number of years a host has been active since their listing's creation date.

  Args:
      data (pandas.DataFrame): The homestay data containing a 'host_since' column.

  Returns:
      pandas.DataFrame: The data with a new 'Host_Tenure' column (in years).
  """
  today = datetime.today()
  df["host_since"] = pd

# %%
def count_amenities(df):
  """
  Counts the number of amenities offered by a listing.

  Args:
      df (pd.DataFrame): Input dataframe containing 'amenities' column.

  Returns:
      pd.DataFrame: Dataframe with a new column 'Amenities_Count' containing the amenity count.
  """
  df['Amenities_Count'] = df['amenities'].apply(len)
  return df

df = count_amenities(df.copy())

# %%
def calculate_days_since_last_review(df):
  """
  Calculates the number of days since the last review was received for a listing.

  Args:
      df (pd.DataFrame): Input dataframe containing 'last_review' column.

  Returns:
      pd.DataFrame: Dataframe with a new column 'Days_Since_Last_Review'.
  """
  def days_since_review(row):
    if pd.isnull(row['last_review']):
      return None
    last_review_date = datetime.strptime(row['last_review'], "%m/%d/%Y")
    today = datetime.today()
    return (today - last_review_date).days

  df['Days_Since_Last_Review'] = df.apply(days_since_review, axis=1)
  return df

df = calculate_days_since_last_review(df.copy())

# %%
import pandas_datareader as pdr

df = pdr.DataReader('F-F_Research_Data_Factors_daily', 'famafrench', start='1900', end='2022')
# Out:
# <ipython-input-39-160091c7d3fe>:3: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df = pdr.DataReader('F-F_Research_Data_Factors_daily', 'famafrench', start='1900', end='2022')

# %%
numerics = df.select_dtypes(include=[np.number])
correlation = numerics.corr()

# Create a heatmap to visualize correlations
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-225d4f57c953> in <cell line: 1>()
# ----> 1 numerics = df.select_dtypes(include=[np.number])
#       2 correlation = numerics.corr()
#       3
#       4 # Create a heatmap to visualize correlations
#       5 plt.figure(figsize=(12, 8))
#
# AttributeError: 'dict' object has no attribute 'select_dtypes'
