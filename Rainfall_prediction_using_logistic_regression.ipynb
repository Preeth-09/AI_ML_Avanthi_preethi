# %% [markdown]
# <a href="https://colab.research.google.com/github/Preeth-09/AI_ML_Avanthi_preethi/blob/main/Rainfall_prediction_using_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/archive (3).zip')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# **While we should be abe to fill in missing values for most columns,it might be a good idea to discard the rows where value for raintoday and rain tomorrow is missing to make our analysis and modelling**

# %%
df.dropna(subset=['RainToday','RainTomorrow'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140787 entries, 0 to 145458
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           140787 non-null  object
#  1   Location       140787 non-null  object
#  2   MinTemp        140319 non-null  float64
#  3   MaxTemp        140480 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81093 non-null   float64
#  6   Sunshine       73982 non-null   float64
#  7   WindGustDir    131624 non-null  object
#  8   WindGustSpeed  131682 non-null  float64
#  9   WindDir9am     131127 non-null  object
#  10  WindDir3pm     137117 non-null  object
#  11  WindSpeed9am   139732 non-null  float64
#  12  WindSpeed3pm   138256 non-null  float64
#  13  Humidity9am    139270 non-null  float64
#  14  Humidity3pm    137286 non-null  float64
#  15  Pressure9am    127044 non-null  float64
#  16  Pressure3pm    127018 non-null  float64
# ...

# %% [markdown]
# DATA ANALYSIS AND VISUALIZATION
#
# **bold text**

# %%
pip install plotly matplotlib seaborn --quiet

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
px.histogram(df,x='Location', title='Location vs. Rainy Days',color='RainToday')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(df,x='Temp3pm',title='Temperature at 3pm vs. Rain Tomorrow', color='RainTomorrow')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# IF THE TEMPERATURE IS LOW THEN RAINFALL IS HIGHER
#
# **bold text**

# %%
px.histogram(df,x='RainTomorrow',color='RainToday',title='Rain Tomorrow vs. Rain Today')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# This is called as class balance

# %%
px.scatter(df.sample(2000),title='Min Temp. vs Max Temp.',x='MinTemp',y='MaxTemp',color='RainToday')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.strip(df.sample(2000),title='Temp (3pm) vs. Humidity (3pm)',x='Temp3pm',y='Humidity3pm',color='RainTomorrow')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# When working with massive datasets containing millions of row, its good idea to work with a sample initially,to quickly set up model.set the value of use_sample to true.(optional)

# %%
use_sample = False

# %%
sample_fraction = 0.1

# %%
if use_sample:
  df=df.sample(frac=sample_fraction).copy()

# %% [markdown]
# Use 60% of the data for training set,20% for validation set,20% for the test set.

# %%
df
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
train_val_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df,val_df = train_test_split(train_val_df, test_size=0.25,random_state=42)

# %%
print('train_df.shape :', train_df.shape)
print('val_df.shape :',val_df.shape)
print('test_df.shape :', test_df.shape)
# Out:
# train_df.shape : (84471, 23)
# val_df.shape : (28158, 23)
# test_df.shape : (28158, 23)

# %%
df
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# while working with dates, its better to seperate the training validation and test sets with time, so that the model is trained on data from the past and evaluted on data from future
# for the current dataset, we use date column in the dataset to create another column for year, we'll pick the last 2 years for the test set and one year before it for the validation set

# %%
plt.title('No.of Rows per Year')
sns.countplot(x=pd.to_datetime(df.Date).dt.year);

# %%
year = pd.to_datetime(df.Date).dt.year
train_df = df[year < 2015]
val_df = df[year == 2015]
test_df = df[year > 2015]

# %%
print('train_df.shape :', train_df.shape)
print('val_df.shape :',val_df.shape)
print('test_df.shape :',test_df.shape)
# Out:
# train_df.shape : (97988, 23)
# val_df.shape : (17089, 23)
# test_df.shape : (25710, 23)

# %% [markdown]
# here, the test validation and test sets contain data for all 12 months

# %%
train_df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 144548  2014-12-27    Uluru     16.9     33.2       0.0          NaN
# 144549  2014-12-28    Uluru     15.1     36.8       0.0          NaN
# 144550  2014-12-29    Uluru     17.3     37.8       0.0          NaN
# 144551  2014-12-30    Uluru     20.1     38.5       0.0          NaN
# 144552  2014-12-31    Uluru     22.5     39.6       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
val_df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 2133    2015-01-01   Albury     11.4     33.5       0.0          NaN
# 2134    2015-01-02   Albury     15.5     39.6       0.0          NaN
# 2135    2015-01-03   Albury     17.1     38.3       0.0          NaN
# 2136    2015-01-04   Albury     26.0     33.1       0.0          NaN
# 2137    2015-01-05   Albury     19.0     35.2       0.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 144913  2015-12-27    Uluru     20.5     34.7       0.0          NaN
# 144914  2015-12-28    Uluru     18.0     36.4       0.0          NaN
# 144915  2015-12-29    Uluru     17.5     37.1       0.0          NaN
# 144916  2015-12-30    Uluru     20.0     38.9       0.0          NaN
# 144917  2015-12-31    Uluru     19.3     37.4       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
test_df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 2498    2016-01-01   Albury     20.4     37.6       0.0          NaN
# 2499    2016-01-02   Albury     20.9     33.6       0.4          NaN
# 2500    2016-01-03   Albury     18.4     23.1       2.2          NaN
# 2501    2016-01-04   Albury     17.3     23.7      15.6          NaN
# 2502    2016-01-05   Albury     15.5     22.9       6.8          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# **Identifying input and target columns**
# we only want to weather conditions to make a prediction anout whether it will rain the next day
# here, we create a list of input columns, and also identify the target column

# %%
input_cols = list(train_df.columns)[1:-1]
target_col ='RainTomorrow'

# %%
print(input_cols)
# Out:
# ['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday']

# %%
target_col
# Out:
# 'RainTomorrow'

# %% [markdown]
# we can now create inputs and targets for the training , validation and test sets for processing and model training

# %%
train_inputs = train_df[input_cols].copy()
train_targets = train_df[target_col].copy()

# %%
val_inputs = val_df[input_cols].copy()
val_targets = val_df[target_col].copy()

# %%
test_inputs = test_df[input_cols].copy()
test_targets = test_df[target_col].copy()

# %%
train_inputs
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 144548    Uluru     16.9     33.2       0.0          NaN       NaN
# 144549    Uluru     15.1     36.8       0.0          NaN       NaN
# 144550    Uluru     17.3     37.8       0.0          NaN       NaN
# 144551    Uluru     20.1     38.5       0.0          NaN       NaN
# 144552    Uluru     22.5     39.6       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  \
# 0                W           44.0          W        WNW  ...          24.0
# ...

# %%
train_targets
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#           ..
# 144548    No
# 144549    No
# 144550    No
# 144551    No
# 144552    No
# Name: RainTomorrow, Length: 97988, dtype: object

# %% [markdown]
# we need to convert the categorial data to numbers for training a logistic regression model

# %%
pip install numpy --quiet

# %%
import numpy as np

# %%
numeric_cols = train_inputs.select_dtypes(include=np.number).columns.tolist()[:-1]
categorial_cols = train_inputs.select_dtypes('object').columns.tolist()

# %%
numeric_cols
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am']

# %% [markdown]
# let's view some statistics for the numeric columns

# %%
train_inputs[numeric_cols].describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  97674.000000  97801.000000  97988.000000  61657.000000  57942.000000
# mean      12.007831     23.022202      2.372935      5.289991      7.609004
# std        6.347175      6.984397      8.518819      3.952010      3.788813
# min       -8.500000     -4.100000      0.000000      0.000000      0.000000
# 25%        7.500000     17.900000      0.000000      2.600000      4.800000
# 50%       11.800000     22.400000      0.000000      4.600000      8.500000
# 75%       16.600000     27.900000      0.800000      7.200000     10.600000
# max       33.900000     48.100000    371.000000     82.400000     14.300000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   91160.000000  97114.000000  96919.000000  96936.000000  96872.000000
# mean       40.215873     14.092263     18.764608     68.628745     51.469547
# ...

# %% [markdown]
# Lets check the no.of categories in each of the categorial columns

# %%
train_inputs[categorial_cols].nunique()
# Out:
# Location       49
# WindGustDir    16
# WindDir9am     16
# WindDir3pm     16
# RainToday       2
# dtype: int64

# %% [markdown]
#  Machine Learning models doesn't work with missing numerical data. The process of filling missing values is called imputation.
#
#
# > IMPUTING MISSING NUMERICA DATA

# %%
from sklearn.impute import SimpleImputer

# %%
# here we get some parameters present in simpleimputer
# ?SimpleImputer

# %%
imputer = SimpleImputer(strategy = 'mean')

# %% [markdown]
# Before we perform imputation, let's check no.of missing values in each column.

# %%
df[numeric_cols].isna().sum()
# Out:
# MinTemp            468
# MaxTemp            307
# Rainfall             0
# Evaporation      59694
# Sunshine         66805
# WindGustSpeed     9105
# WindSpeed9am      1055
# WindSpeed3pm      2531
# Humidity9am       1517
# Humidity3pm       3501
# Pressure9am      13743
# Pressure3pm      13769
# Cloud9am         52625
# Cloud3pm         56094
# Temp9am            656
# dtype: int64

# %% [markdown]
#  These values are spread across the training, test and validation sets.you can also  check them individually like train_inputs, val_inputs

# %%
train_inputs[numeric_cols].isna().sum()
# Out:
# MinTemp            314
# MaxTemp            187
# Rainfall             0
# Evaporation      36331
# Sunshine         40046
# WindGustSpeed     6828
# WindSpeed9am       874
# WindSpeed3pm      1069
# Humidity9am       1052
# Humidity3pm       1116
# Pressure9am       9112
# Pressure3pm       9131
# Cloud9am         34988
# Cloud3pm         36022
# Temp9am            574
# dtype: int64

# %%
df[numeric_cols]
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          NaN       NaN           44.0
# 1           7.4     25.1       0.0          NaN       NaN           44.0
# 2          12.9     25.7       0.0          NaN       NaN           46.0
# 3           9.2     28.0       0.0          NaN       NaN           24.0
# 4          17.5     32.3       1.0          NaN       NaN           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145454      3.5     21.8       0.0          NaN       NaN           31.0
# 145455      2.8     23.4       0.0          NaN       NaN           31.0
# 145456      3.6     25.3       0.0          NaN       NaN           22.0
# 145457      5.4     26.9       0.0          NaN       NaN           37.0
# 145458      7.8     27.0       0.0          NaN       NaN           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
imputer.fit(df[numeric_cols])
# Out:
# SimpleImputer()

# %% [markdown]
# After calling fit, the computed statistic for each column is stored in the statistics_ property of imputer.

# %%
print(numeric_cols)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am']

# %%
list(imputer.statistics_)
# Out:
# [12.18482386562048,
#  23.235120301822324,
#  2.349974074310839,
#  5.472515506887154,
#  7.630539861047281,
#  39.97051988882308,
#  13.990496092519967,
#  18.631140782316862,
#  68.82683277087672,
#  51.44928834695453,
#  1017.6545771543717,
#  1015.2579625879797,
#  4.431160817585808,
#  4.499250233195188,
#  16.98706638787991]

# %% [markdown]
# The missing values in the training ,test and validaton sets can be now filledin using the transform method of imputer

# %%
 imputer.transform(train_inputs[numeric_cols])
# Out:
# array([[13.4       , 22.9       ,  0.6       , ...,  8.        ,
#          4.49925023, 16.9       ],
#        [ 7.4       , 25.1       ,  0.        , ...,  4.43116082,
#          4.49925023, 17.2       ],
#        [12.9       , 25.7       ,  0.        , ...,  4.43116082,
#          2.        , 21.        ],
#        ...,
#        [17.3       , 37.8       ,  0.        , ...,  4.43116082,
#          4.49925023, 29.7       ],
#        [20.1       , 38.5       ,  0.        , ...,  4.43116082,
#          4.49925023, 29.8       ],
#        [22.5       , 39.6       ,  0.        , ...,  4.43116082,
#          4.49925023, 30.1       ]])

# %%
train_inputs[numeric_cols] = imputer.transform(train_inputs[numeric_cols])
val_inputs[numeric_cols] = imputer.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols] = imputer.transform(test_inputs[numeric_cols])

# %% [markdown]
# The missing values are now filled with the mean of each column.

# %%
train_inputs[numeric_cols].isna().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# dtype: int64

# %% [markdown]
# SCALING NUMERIC FEATURES

# %%
df[numeric_cols].describe()
# Out:
#              MinTemp       MaxTemp       Rainfall   Evaporation      Sunshine  \
# count  140319.000000  140480.00000  140787.000000  81093.000000  73982.000000
# mean       12.184824      23.23512       2.349974      5.472516      7.630540
# std         6.403879       7.11450       8.465173      4.189132      3.781729
# min        -8.500000      -4.80000       0.000000      0.000000      0.000000
# 25%         7.600000      17.90000       0.000000      2.600000      4.900000
# 50%        12.000000      22.60000       0.000000      4.800000      8.500000
# 75%        16.800000      28.30000       0.800000      7.400000     10.700000
# max        33.900000      48.10000     371.000000    145.000000     14.500000
#
#        WindGustSpeed   WindSpeed9am   WindSpeed3pm    Humidity9am  \
# count  131682.000000  139732.000000  138256.000000  139270.000000
# mean       39.970520      13.990496      18.631141      68.826833
# std        13.578201       8.886210       8.798096      19.063650
# ...

# %% [markdown]
# Lets use MinMaxScaler from sklearn.preprocessing to scale values to the (0,1) range

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# ?MinMaxScaler

# %%
scaler = MinMaxScaler()

# %% [markdown]
# First, we fit the scaler to the data i.e. compute the range of values for each numeric column.

# %%
scaler.fit(df[numeric_cols])
# Out:
# MinMaxScaler()

# %% [markdown]
# we can now inspect the minimum and maximum values in each column

# %%
print(numeric_cols)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am']

# %%
print('Minimum:')
list(scaler.data_min_)
# Out:
# Minimum:
# [-8.5,
#  -4.8,
#  0.0,
#  0.0,
#  0.0,
#  6.0,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  980.5,
#  977.1,
#  0.0,
#  0.0,
#  -7.2]

# %%
print('Maximum:')
list(scaler.data_max_)
# Out:
# Maximum:
# [33.9,
#  48.1,
#  371.0,
#  145.0,
#  14.5,
#  135.0,
#  130.0,
#  87.0,
#  100.0,
#  100.0,
#  1041.0,
#  1039.6,
#  9.0,
#  9.0,
#  40.2]

# %%
train_inputs[numeric_cols] = scaler.transform(train_inputs[numeric_cols])
val_inputs[numeric_cols] = scaler.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols] = scaler.transform(test_inputs[numeric_cols])

# %%
train_inputs[numeric_cols].describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  97988.000000  97988.000000  97988.000000  97988.000000  97988.000000
# mean       0.483689      0.525947      0.006396      0.036949      0.525366
# std        0.149458      0.131904      0.022962      0.021628      0.200931
# min        0.000000      0.013233      0.000000      0.000000      0.000000
# 25%        0.377358      0.429112      0.000000      0.026207      0.517241
# 50%        0.478774      0.514178      0.000000      0.037741      0.526244
# 75%        0.591981      0.618147      0.002156      0.038621      0.634483
# max        1.000000      1.000000      1.000000      0.568276      0.986207
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   97988.000000  97988.000000  97988.000000  97988.000000  97988.000000
# mean        0.265107      0.108395      0.215668      0.686309      0.514693
# ...
